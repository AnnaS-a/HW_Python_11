# %% [markdown]
# f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30
#
# 1. Определить корни
#
# 2. Найти интервалы, на которых функция возрастает
#
# 3. Найти интервалы, на которых функция убывает
#
# 4. Построить график
#
# 5. Вычислить вершину
#
# 6. Определить промежутки, на котором f > 0
#
# 7. Определить промежутки, на котором f < 0

# %%
import sympy
import matplotlib.pyplot as plt
import numpy as np
from numpy import sin, cos
from sympy.plotting import plot

# %%
x = sympy.symbols('x')

# %%
f = -12 * x ** 4 * sympy.sin(sympy.cos(x)) - 18 * x ** 3 + 5 * x ** 2 + 10 * x -30

# %%
ans = sympy.plot(f)

# %%
f = -12 * x ** 4 * sympy.sin(sympy.cos(x)) - 18 * x ** 3 + 5 * x ** 2 + 10 * x -30
#xs = np.linspace(-8, -5, 2)  
#yvals = [f.subs(x, xi) for xi in xs]
plot = sympy.plot(f, xlim=[-9, -3], ylim=[-500, 500])

plot = sympy.plot(f, xlim=[-3, 1], ylim=[-500, 500])

plot = sympy.plot(f, xlim=[1, 9], ylim=[-500, 500])

# %%
ans = sympy.solveset(f)

# %%
ans
# Out:
# ConditionSet(x, Eq(12*x**4*sin(x)*cos(cos(x)) - 48*x**3*sin(cos(x)) - 54*x**2 + 10*x + 10, 0), Complexes)

# %% [markdown]
# Корни уравнения (точки пересечения с осью x).
# Взят отрезок на координатной прямой от -10 до 10.
# На графиках, с увеличенным масштабом, видим, что данная функция имеет шесть корней.
# С помощью графика, находим приблизительное значение корней уравнения: -7,6; -5; -1,3; 2,25; 4,4; 8.

# %% [markdown]
# При x < 7,6; на интервалах (-5; -1.3), (2,25; 4,4) и при x > 8 функция f > 0.
# При x на интервалах (-7,6; -5), (-1,3; 2,25), (4,4; 8) функция f < 0.

# %%
f, ff = sympy.symbols('f ff')
f = -12 * x ** 4 * sympy.sin(sympy.cos(x)) - 18 * x ** 3 + 5 * x ** 2 + 10 * x -30

# %%
ff = sympy.diff(f)

# %%
ff
# Out:
# 12*x**4*sin(x)*cos(cos(x)) - 48*x**3*sin(cos(x)) - 54*x**2 + 10*x + 10

# %% [markdown]
# Производная функции f

# %%
ans = sympy.solveset(ff)

# %%
ans
# Out:
# ConditionSet(x, Eq(12*x**4*sin(x)*cos(cos(x)) - 48*x**3*sin(cos(x)) - 54*x**2 + 10*x + 10, 0), Complexes)

# %% [markdown]
# На графике функции вершин, т.к. присутствуют функции sin и cos.
# Посмотрим вершины на интервале [-20, 20].

# %%
x = sympy.symbols('x')
f = -12 * x ** 4 * sympy.sin(sympy.cos(x)) - 18 * x ** 3 + 5 * x ** 2 + 10 * x -30

# %%
plot = sympy.plot(f, xlim=[-15, 15], ylim=[-40000, 80000])

# %% [markdown]
# Вершины графика функции примерно находятся в точках с абциссами -6,8;   -4,3;   1,6;   3,85;   7;   9,8.

# %%
plot = sympy.plot(f, xlim=[-10, -6], ylim=[-15000, 0])

# %% [markdown]
# Вершина графика функции f (минимум) х = -6,8

# %%
plot = sympy.plot(f, xlim=[-5, -3], ylim=[0, 5000])

# %% [markdown]
# Вершина графика функции f (максимум) х = -4,3

# %%
plot = sympy.plot(f, xlim=[-2, 4], ylim=[-500, 500])

# %% [markdown]
# Вершина графика функции f (минимум) х = 1,6

# %%
plot = sympy.plot(f, xlim=[3,5, 4,5], ylim=[0, 5000])

# %% [markdown]
# Вершина графика функции f (максимум) х = 3,85

# %%
plot = sympy.plot(f, xlim=[5, 8], ylim=[-30000, 0])

# %% [markdown]
# Вершина графика функции f (минимум) х = 7

# %%
plot = sympy.plot(f, xlim=[4, 12], ylim=[0, 80000])

# %% [markdown]
# Вершина графика функции f (максимум) х = 9,8

# %%
ff = 12 * 𝑥**4 * sympy.sin(𝑥) * sympy.cos(sympy.cos(𝑥)) - 48 * 𝑥**3 * sympy.sin(sympy.cos(𝑥)) - 54 * 𝑥**2 + 10 * 𝑥 + 10

# %%
a = sympy.plot(ff)

# %% [markdown]
# График производной функции f.

# %% [markdown]
# При x < -6,8 и на интервалах (4,3; 1,6), (3,85; 7), x > 9,8 производная < 0 и функция f убывает.
#
# При x > на интервалах (-6,8; 4,3), (1,6; 3,85), (7; 9.8) производная > 0 и функция f возрастает.
